# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
fig = plt.figure(figsize=(8, 6), dpi=80)
ax = fig.add_subplot()

# %%
plt.plot([1,2,3,4], [1,8,8,16], color="green", linewidth=1)

# %%
plt.scatter([1,2,3,4], [1,4,8,16], color="green", marker='D')

# %%
plt.bar([1,2,3,4], [1,4,8,16], color="red", width=0.5, align='center')
# Out:
# <BarContainer object of 4 artists>

# %%
lst = [1,2,3,4,5,6,3,7,3,2,5.7,14,14,15,15]

# %%
plt.hist(lst, 6, width=0.9, color='red')
# Out:
# (array([6., 2., 3., 0., 0., 4.]),
#  array([ 1.        ,  3.33333333,  5.66666667,  8.        , 10.33333333,
#         12.66666667, 15.        ]),
#  <BarContainer object of 6 artists>)

# %%
sales = pd.read_excel('goods.xlsx')
sns.set_style('darkgrid')
sns.set_palette('husl')
sns.lineplot(data=sales, x='item_name', y='price')
# Out:
# <AxesSubplot: xlabel='item_name', ylabel='price'>

# %%
sales = pd.read_excel('goods.xlsx')
sales.head()
# Out:
#   item_name  price  items_sold           type
# 0     socks      2          21  underclothing
# 1  trousers     15           7       clothing
# 2     shirt      8          23       clothing
# 3     skirt      9           6       clothing
# 4     boots     18          10          shoes

# %%
sns.boxplot(x='type', y="items_sold", data=sales)
# Out:
# <AxesSubplot: xlabel='type', ylabel='items_sold'>
