# %% [markdown]
# ### Task 1

# %% [markdown]
# 1. Два економісти заповнюють документи з власними прогнозами щодо курсу певних коштовних паперів, після чого їх складають у спільну папку. Ймовірність відхилення прогнозованого значення курсу від фактичного понад допустиму похибку для першого економіста дорівнює 0,1; для другого 0,2. Перший економіст заповнив 40 документів, другий - 60. Під час перевірки навмання взятий із папки документ виявився з суттєвою похибкою. Визначити ймовірність того, що його склав перший економіст.

# %% [markdown]
# Позначимо події H1, H2 – документ заповнив відповідно перший, другий економіст, А – навмання взятий із папки документ виявився з суттєвою похибкою. Тоді за умовою P(H1)=40/100=0,4; P(H2)=60/100=0,6; p(A|H1)=0,1; P(A|H2)=0,2

# %% [markdown]
# За формулою повної ймовірності P(A)=P(H1)P(A|H1)+P(H2)P(A|H2)=0,4*0.1+0,6*0,2=0,16

# %% [markdown]
# За формулою Байєса отримаємо P(H1|A)=(P(h1)P(A|H1))/P(A)=0,4*0,1/0,16=0,25

# %% [markdown]
# Отже, ймовірність заповнення документа з суттєвою похибкою першим економістом P(H1|A)=0,25

# %% [markdown]
# ### Task 2

# %% [markdown]
# 2. Є можливість вибрати спосіб виробництва і реалізації двох наборів товарів широкого вжитку. За даними відділу маркетингу, яким були проведені дослідження ринку, можливий прибуток від виробництва і реалізації X і У наведено в таблицях (X, Y - прибуток у грошових одиницях):
# ![IMG](data:image/png;base64,...)
# Потрібно оцінити ступінь ризику і запропонувати рішення щодо випуску і реалізації одного із наборів товарів.

# %% [markdown]
# Знаходимо математичне сподівання можливого прибутку для кожного варіанта:
#
# M(X)=1000*0,5+1500*0,3+2000*0,2=1350;
#
# M(Y)=1000*0,4+1500*0,4+1750*0,2=1350.

# %% [markdown]
# Обидва варіанти мають однакове математичне сподівання можливого прибутку. Оцінюємо ступінь ризику кожного варіанта:

# %% [markdown]
# D(X)=(1000-1350) ** 2 * 0,5 + (1500-1350) ** 2 * 0,3 + (2000-1350) ** 2 * 0,2 = 61250+6750+84500=152500, σ(X) = 390,5

# %% [markdown]
# D(Y)=(1000-1350) ** 2 * 0,4 + (1500-1350) ** 2 * 0,4 + (1750-1350) ** 2 * 0,2 = 49000+9000+32000 = 90000, σ(Y)=300

# %% [markdown]
# #### Ступінь ризику, пов’язаний з виробництвом і реалізацією набору Х більший, ніж набору Y.
#
# #### Варіант Y менш ризикований.
